# %% [markdown]
# # Análisis de la temperatura

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import seaborn as sns

# %%
pathFile="C:\\Users\\User\\Downloads\\Datos_Hidrometeorol_gicos_Crudos_-_Red_de_Estaciones_IDEAM___Temperatura_20250129.csv"
df = pd.read_csv(pathFile)
print(df)
# Out:
#           CodigoEstacion  CodigoSensor        FechaObservacion  \
# 0               29045000            68  08/01/2015 03:00:00 PM
# 1               21055501            68  06/23/2019 02:15:00 PM
# 2               35035130            68  07/09/2015 02:00:00 AM
# 3               21205502            68  11/22/2018 06:20:00 AM
# 4               26065502            68  06/09/2016 05:40:00 AM
# ...                  ...           ...                     ...
# 81764747        35085080            68  04/13/2017 12:00:00 PM
# 81764748        29065501            68  11/20/2018 06:05:00 AM
# 81764749        21206950            68  06/21/2007 06:00:00 PM
# 81764750        52025501            68  04/13/2019 04:05:00 AM
# 81764751        23065501            68  09/17/2016 07:45:00 AM
#
#           ValorObservado             NombreEstacion  Departamento  \
# 0               35.50000        SABANALARGA TX GPRS     ATLÁNTICO
# 1               20.58631        SIMON CAMPOS  - AUT         HUILA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81764752 entries, 0 to 81764751
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   CodigoEstacion     int64
#  1   CodigoSensor       int64
#  2   FechaObservacion   object
#  3   ValorObservado     float64
#  4   NombreEstacion     object
#  5   Departamento       object
#  6   Municipio          object
#  7   ZonaHidrografica   object
#  8   Latitud            float64
#  9   Longitud           float64
#  10  DescripcionSensor  object
#  11  UnidadMedida       object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 7.3+ GB

# %%
departamentos=df['Departamento'].unique()
print(departamentos)
# Out:
# ['ATLÁNTICO' 'HUILA' 'CUNDINAMARCA' 'CAUCA' 'META' 'BOYACÁ'
#  'VALLE DEL CAUCA' 'CESAR' 'BOGOTA D.C.' 'MAGDALENA' 'TOLIMA' 'CALDAS'
#  'NORTE DE SANTANDER' 'CHOCÓ' 'NARIÑO' 'ANTIOQUIA' 'RISARALDA' 'PUTUMAYO'
#  'BOGOTA' 'SANTANDER' 'SUCRE' 'CHOCO' 'BOLIVAR' 'CASANARE' 'BOLÍVAR'
#  'QUINDÍO' 'ATLANTICO' 'CÓRDOBA' 'CAQUETA' 'LA GUAJIRA' 'CORDOBA'
#  'AMAZONAS' 'NARINO' 'GUAINÍA' 'ARAUCA' 'SAN ANDRÉS PROVIDENCIA'
#  'GUAVIARE' '<nil>' 'VAUPÉS' 'VICHADA'
#  'ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANTA CATALINA' 'BOGOTÁ'
#  'ARCHIPIÉLAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA' 'CAQUETÁ'
#  'ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA']

# %% [markdown]
# ## Datos del Magdalena

# %%
datosMagdalena= df[df['Departamento']=='MAGDALENA']
print(datosMagdalena)
# Out:
#           CodigoEstacion  CodigoSensor        FechaObservacion  \
# 15              29065501            68  06/27/2017 11:10:00 AM
# 19              29065130            68  06/29/2017 05:00:00 PM
# 25              29065130            68  02/18/2015 10:00:00 AM
# 63              29065130            68  07/12/2010 08:00:00 AM
# 155             15015120            68  09/15/2018 09:00:00 PM
# ...                  ...           ...                     ...
# 81764522        29065000            68  08/15/2019 05:00:00 PM
# 81764675        29065000            68  10/02/2017 04:00:00 AM
# 81764692        29065120            68  03/09/2010 03:00:00 PM
# 81764731        29065501            68  12/21/2017 09:15:00 AM
# 81764748        29065501            68  11/20/2018 06:05:00 AM
#
#           ValorObservado                  NombreEstacion Departamento  \
# 15              22.58378               CIENAGA,LA  - AUT    MAGDALENA
# ...

# %%
fechasObservacionesMagdalena=datosMagdalena['FechaObservacion'].unique()
print(fechasObservacionesMagdalena)

nombreEstacionesMagdalena=datosMagdalena['NombreEstacion'].unique()
print(nombreEstacionesMagdalena)
# Out:
# ['06/27/2017 11:10:00 AM' '06/29/2017 05:00:00 PM'
#  '02/18/2015 10:00:00 AM' ... '09/26/2006 08:00:00 AM'
#  '12/21/2017 09:15:00 AM' '11/20/2018 06:05:00 AM']
# ['CIENAGA,LA  - AUT' 'LA GRAN VIA - AUT' 'UNIVERSIDAD TECNOLOGICA  - AUT'
#  'EL DIFICIL - AUT' 'MEDIA LUNA - AUT' 'AEROPUERTO LAS FLORES  - AUT'
#  'BATALLON NO. 6 - AUT' 'LOS ALAMOS' 'COLEGIO KANKAWARWA'
#  'SAN ISIDRO BONDA - AUT' 'PALMOR - SIERRA NEVADA - AUT'
#  'SAN LORENZO  - AUT' 'GUACHACA - AUT' 'PARQUE TAYRONA'
#  'AEROPUERTO SIMON BOLIVAR' 'UNIVERSIDAD TECNOLOGICA'
#  'AEROPUERTO LAS FLORES' 'MEDIA LUNA' 'LA GRAN VIA' 'BATALLON NO. 6']

# %% [markdown]
# ## Datos estación Ciénaga

# %%
datoCienaga=datosMagdalena[(datosMagdalena['NombreEstacion']=='CIENAGA,LA  - AUT')]
print(datoCienaga)
# Out:
#           CodigoEstacion  CodigoSensor        FechaObservacion  \
# 15              29065501            68  06/27/2017 11:10:00 AM
# 281             29065501            68  10/27/2018 09:25:00 AM
# 584             29065501            68  03/07/2019 06:00:00 AM
# 813             29065501            68  03/12/2018 02:35:00 PM
# 866             29065501            68  10/28/2017 02:55:00 AM
# ...                  ...           ...                     ...
# 81763940        29065501            68  05/24/2019 12:50:00 PM
# 81764054        29065501            68  10/24/2017 09:20:00 PM
# 81764134        29065501            68  10/30/2017 05:20:00 AM
# 81764731        29065501            68  12/21/2017 09:15:00 AM
# 81764748        29065501            68  11/20/2018 06:05:00 AM
#
#           ValorObservado     NombreEstacion Departamento Municipio  \
# 15              22.58378  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# 281             22.94454  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# ...

# %%
display(datoCienaga)
# Out:
#           CodigoEstacion  CodigoSensor        FechaObservacion  \
# 15              29065501            68  06/27/2017 11:10:00 AM
# 281             29065501            68  10/27/2018 09:25:00 AM
# 584             29065501            68  03/07/2019 06:00:00 AM
# 813             29065501            68  03/12/2018 02:35:00 PM
# 866             29065501            68  10/28/2017 02:55:00 AM
# ...                  ...           ...                     ...
# 81763940        29065501            68  05/24/2019 12:50:00 PM
# 81764054        29065501            68  10/24/2017 09:20:00 PM
# 81764134        29065501            68  10/30/2017 05:20:00 AM
# 81764731        29065501            68  12/21/2017 09:15:00 AM
# 81764748        29065501            68  11/20/2018 06:05:00 AM
#
#           ValorObservado     NombreEstacion Departamento Municipio  \
# 15              22.58378  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# 281             22.94454  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# ...

# %%
FechaObservacionZonaEstudio=datoCienaga['FechaObservacion'].unique()
print(FechaObservacionZonaEstudio)
# Out:
# ['06/27/2017 11:10:00 AM' '10/27/2018 09:25:00 AM'
#  '03/07/2019 06:00:00 AM' ... '10/30/2017 05:20:00 AM'
#  '12/21/2017 09:15:00 AM' '11/20/2018 06:05:00 AM']

# %% [markdown]
# ## Gráficos Estación Ciénaga

# %%
#datosanio2017=datosMagdalena[(datosMagdalena['FechaObservacion']=='CIENAGA,LA  - AUT')]
new_datos_Cienaga = datoCienaga.assign(Fecha=0)

# %%
display(new_datos_Cienaga)
# Out:
#           CodigoEstacion  CodigoSensor        FechaObservacion  \
# 15              29065501            68  06/27/2017 11:10:00 AM
# 281             29065501            68  10/27/2018 09:25:00 AM
# 584             29065501            68  03/07/2019 06:00:00 AM
# 813             29065501            68  03/12/2018 02:35:00 PM
# 866             29065501            68  10/28/2017 02:55:00 AM
# ...                  ...           ...                     ...
# 81763940        29065501            68  05/24/2019 12:50:00 PM
# 81764054        29065501            68  10/24/2017 09:20:00 PM
# 81764134        29065501            68  10/30/2017 05:20:00 AM
# 81764731        29065501            68  12/21/2017 09:15:00 AM
# 81764748        29065501            68  11/20/2018 06:05:00 AM
#
#           ValorObservado     NombreEstacion Departamento Municipio  \
# 15              22.58378  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# 281             22.94454  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# ...

# %%
display(new_datos_Cienaga)
# Out:
#           CodigoEstacion  CodigoSensor        FechaObservacion  \
# 15              29065501            68  06/27/2017 11:10:00 AM
# 281             29065501            68  10/27/2018 09:25:00 AM
# 584             29065501            68  03/07/2019 06:00:00 AM
# 813             29065501            68  03/12/2018 02:35:00 PM
# 866             29065501            68  10/28/2017 02:55:00 AM
# ...                  ...           ...                     ...
# 81763940        29065501            68  05/24/2019 12:50:00 PM
# 81764054        29065501            68  10/24/2017 09:20:00 PM
# 81764134        29065501            68  10/30/2017 05:20:00 AM
# 81764731        29065501            68  12/21/2017 09:15:00 AM
# 81764748        29065501            68  11/20/2018 06:05:00 AM
#
#           ValorObservado     NombreEstacion Departamento Municipio  \
# 15              22.58378  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# 281             22.94454  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# ...

# %%
from datetime import datetime as dt
datoCienaga['Fecha']=[ dt.strptime(s,'%m/%d/%Y %H:%M:%S %p').strftime('%d/%m/%Y')  for s in  datoCienaga['FechaObservacion']]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14428\4018417381.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datoCienaga['Fecha']=[ dt.strptime(s,'%m/%d/%Y %H:%M:%S %p').strftime('%d/%m/%Y')  for s in  datoCienaga['FechaObservacion']]

# %%
display(datoCienaga)
# Out:
#           CodigoEstacion  CodigoSensor        FechaObservacion  \
# 15              29065501            68  06/27/2017 11:10:00 AM
# 281             29065501            68  10/27/2018 09:25:00 AM
# 584             29065501            68  03/07/2019 06:00:00 AM
# 813             29065501            68  03/12/2018 02:35:00 PM
# 866             29065501            68  10/28/2017 02:55:00 AM
# ...                  ...           ...                     ...
# 81763940        29065501            68  05/24/2019 12:50:00 PM
# 81764054        29065501            68  10/24/2017 09:20:00 PM
# 81764134        29065501            68  10/30/2017 05:20:00 AM
# 81764731        29065501            68  12/21/2017 09:15:00 AM
# 81764748        29065501            68  11/20/2018 06:05:00 AM
#
#           ValorObservado     NombreEstacion Departamento Municipio  \
# 15              22.58378  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# 281             22.94454  CIENAGA,LA  - AUT    MAGDALENA   CIÉNAGA
# ...
