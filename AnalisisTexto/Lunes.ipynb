# %% [markdown]
# ## Control de Asistencia

# %%
import pandas as pd
import re

matriculados= pd.read_excel("C:\\Users\\User\\Downloads\\ControlAsistencia\\Lunes\\MatriculadosLunes.xlsx") 
matriculados['NombreSinEspacios']=(matriculados['Nombre'].str.replace(" ",""))
display(matriculados)
# Out:
#     No.      Código                              Nombre  \
# 0     1  2023115033             JESUS ANDRES AROCA PAEZ
# 1     3  2023115045             ANTONIO JOSE CUZA CAMPO
# 2     4  2023115072          SERGIO LUIS FLOREZ SAUCEDO
# 3     5  2023115012   SEBASTIAN MAURICIO GUARDIOLA RIOS
# 4     6  2023115061          DULCE MARIA MENDEZ FUENTES
# 5     7  2021215104     DANIEL EDUARDO NAVARRO PALOMINO
# 6     8  2023115011    SANTIAGO ANDRES NIEVES CERVANTES
# 7     9  2023115066           ANYIS PAOLA PADILLA VILLA
# 8    10  2014215057          ISAI ALBERTO PLATA OROZCO
# 9    11  2023115042        CARLOS JULIO QUINTERO ACOSTA
# 10   12  2023115062        EDINSON DAVID RAMIREZ LARIOS
# 11   13  2022215044      NATALIA CAROLINA RIASCOS BORJA
# 12   14  2023115034        XIMENA ALEJANDRA RIVAS LOPEZ
# 13   15  2023115037        ANDRES FELIPE ROJAS CARRILLO
#
#                  NombreSinEspacios
# 0             JESUSANDRESAROCAPAEZ
# 1             ANTONIOJOSECUZACAMPO
# 2          SERGIOLUISFLOREZSAUCEDO
# 3   SEBASTIANMAURICIOGUARDIOLARIOS
# 4          DULCEMARIAMENDEZFUENTES
# 5     DANIELEDUARDONAVARROPALOMINO
# 6    SANTIAGOANDRESNIEVESCERVANTES
# 7           ANYISPAOLAPADILLAVILLA
# 8           ISAIALBERTOPLATAOROZCO
# 9        CARLOSJULIOQUINTEROACOSTA
# 10       EDINSONDAVIDRAMIREZLARIOS
# 11     NATALIACAROLINARIASCOSBORJA
# 12       XIMENAALEJANDRARIVASLOPEZ
# 13       ANDRESFELIPEROJASCARRILLO

# %%
fecha="26-05-2025"
asistencia= pd.read_csv("C:\\Users\\User\\Downloads\\ControlAsistencia\\Lunes\\"+fecha+".csv",sep="\t",encoding="UTF-16")
asistencia['Nombre1']=asistencia['Nombre completo'].str.replace(" ","")
display(asistencia)
# Out:
#                       Nombre completo Acción del usuario  Marca de tiempo  \
# 0                Daniel Gonzalez Polo              Unido              NaN
# 1             ANTONIO JOSE CUZA CAMPO              Unido              NaN
# 2        CARLOS JULIO QUINTERO ACOSTA              Unido              NaN
# 3    SANTIAGO ANDRES NIEVES CERVANTES              Unido              NaN
# 4          DULCE MARIA MENDEZ FUENTES              Unido              NaN
# 5           ANYIS PAOLA PADILLA VILLA              Unido              NaN
# 6        XIMENA ALEJANDRA RIVAS LOPEZ              Unido              NaN
# 7         SERGIO LUIS  FLOREZ SAUCEDO              Unido              NaN
# 8   SEBASTIAN MAURICIO GUARDIOLA RIOS              Unido              NaN
# 9        ANDRES FELIPE ROJAS CARRILLO              Unido              NaN
# 10       ANDRES FELIPE ROJAS CARRILLO           Abandonó              NaN
# 11       ANDRES FELIPE ROJAS CARRILLO              Unido              NaN
# 12            JESUS ANDRES AROCA PAEZ              Unido              NaN
# 13     NATALIA CAROLINA RIASCOS BORJA              Unido              NaN
# 14       EDINSON DAVID RAMIREZ LARIOS              Unido              NaN
# 15       EDINSON DAVID RAMIREZ LARIOS           Abandonó              NaN
# 16       EDINSON DAVID RAMIREZ LARIOS              Unido              NaN
# 17    DANIEL EDUARDO NAVARRO PALOMINO              Unido              NaN
#
#                            Nombre1
# 0               DanielGonzalezPolo
# 1             ANTONIOJOSECUZACAMPO
# 2        CARLOSJULIOQUINTEROACOSTA
# 3    SANTIAGOANDRESNIEVESCERVANTES
# 4          DULCEMARIAMENDEZFUENTES
# 5           ANYISPAOLAPADILLAVILLA
# 6        XIMENAALEJANDRARIVASLOPEZ
# 7          SERGIOLUISFLOREZSAUCEDO
# 8   SEBASTIANMAURICIOGUARDIOLARIOS
# 9        ANDRESFELIPEROJASCARRILLO
# 10       ANDRESFELIPEROJASCARRILLO
# 11       ANDRESFELIPEROJASCARRILLO
# 12            JESUSANDRESAROCAPAEZ
# 13     NATALIACAROLINARIASCOSBORJA
# 14       EDINSONDAVIDRAMIREZLARIOS
# 15       EDINSONDAVIDRAMIREZLARIOS
# 16       EDINSONDAVIDRAMIREZLARIOS
# 17    DANIELEDUARDONAVARROPALOMINO

# %% [markdown]
# ## Controlando asistencia

# %%
asistenciaNoRepetida=asistencia["Nombre1"].unique()

asistio = set()
noAsistio=[]
for nses, n in   zip(matriculados["NombreSinEspacios"],matriculados["Nombre"]):    
    if nses in asistenciaNoRepetida:
        asistio.add(n) 
    else:
        noAsistio.append(n)   
    

print("\n Asistió........."+str(fecha)+" \n")
for e in asistio:
    print(e)

print("\n------------No Asisitió-------------- "+str(fecha))
for na in noAsistio:
    print(na)
# Out:
#  Asistió.........26-05-2025
#
#  JESUS ANDRES AROCA PAEZ
# ANYIS PAOLA PADILLA VILLA
#  NATALIA CAROLINA RIASCOS BORJA
#  XIMENA ALEJANDRA RIVAS LOPEZ
#  CARLOS JULIO QUINTERO ACOSTA
#  EDINSON DAVID RAMIREZ LARIOS
#  ANTONIO JOSE CUZA CAMPO
#  DANIEL EDUARDO NAVARRO PALOMINO
#  SEBASTIAN MAURICIO GUARDIOLA RIOS
#  DULCE MARIA MENDEZ FUENTES
# SANTIAGO ANDRES NIEVES CERVANTES
#  SERGIO LUIS FLOREZ SAUCEDO
#  ANDRES FELIPE ROJAS CARRILLO
#
# ------------No Asisitió-------------- 26-05-2025
# ISAI ALBERTO PLATA OROZCO

# %%
dfInasistencia = pd.DataFrame(noAsistio, columns=['Nombre Estudiante'])
dfInasistencia["Fecha"]=fecha

Inasistencia= pd.read_excel("C:\\Users\\User\\Downloads\\ControlAsistencia\\Lunes\\InasistenciaLunes.xlsx") 
frames = [Inasistencia,dfInasistencia]
result = pd.concat(frames)
result.to_excel("C:\\Users\\User\\Downloads\\ControlAsistencia\\Lunes\\InasistenciaLunes.xlsx",index=False)
print(result)
# Out:
#                     Nombre Estudiante                Fecha  \
# 0          ISAI ALBERTO PLATA OROZCO            17-02-2025
# 1    KARELIN DANIELA CABAS DE LA CRUZ           24-02-2025
# 2    KARELIN DANIELA CABAS DE LA CRUZ           17-03-2025
# 3          ISAI ALBERTO PLATA OROZCO            17-03-2025
# 4                       SERGIO FLOREZ  2025-03-31 00:00:00
# 5    KARELIN DANIELA CABAS DE LA CRUZ           31-03-2025
# 6          ISAI ALBERTO PLATA OROZCO            31-03-2025
# 7          ISAI ALBERTO PLATA OROZCO            07-04-2025
# 8           ANYIS PAOLA PADILLA VILLA           21-04-2025
# 9          ISAI ALBERTO PLATA OROZCO            21-04-2025
# 10         ISAI ALBERTO PLATA OROZCO            28-04-2025
# 11       XIMENA ALEJANDRA RIVAS LOPEZ           28-04-2025
# 12         DULCE MARIA MENDEZ FUENTES            5-05-2025
# 13         ISAI ALBERTO PLATA OROZCO             5-05-2025
# 14       CARLOS JULIO QUINTERO ACOSTA            5-05-2025
# 15            JESUS ANDRES AROCA PAEZ           12-05-2025
# 16         ISAI ALBERTO PLATA OROZCO            12-05-2025
# 17         ISAI ALBERTO PLATA OROZCO            19-05-2025
# 0          ISAI ALBERTO PLATA OROZCO            26-05-2025
#
#                     Unnamed: 2
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4   Se ausento sin explicación
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 0                          NaN
