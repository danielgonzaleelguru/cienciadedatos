# %% [markdown]
# ## Control de Asistencia

# %% [markdown]
# ## Matriculados

# %%
import pandas as pd
import re

matriculados= pd.read_excel("C:\\Users\\User\\Downloads\\ControlAsistencia\\Viernes\\Matriculados.xlsx") 
matriculados['NombreSinEspacios']=(matriculados['Nombre'].str.replace(" ",""))
display(matriculados)
# Out:
#     No.      Código                           Nombre  Firma  \
# 0     1  2021115080  MAICOL GUILLERMO ASCANIO SILVA     NaN
# 1     2  2023115017        LUIS MIGUEL BECERRA DIAZ     NaN
# 2     3  2021215117      ANDY YULIETH BOLANO  SILVA     NaN
# 3     4  2022215042   DANIELA MARSELA BOLANO TORRES     NaN
# 4     5  2023115018        SAMUEL DAVID GUERRA VEGA     NaN
# 5     6  2023115044       JORGE ANDRES LARA AGUILAR     NaN
# 6     8  2023115005  NATALIA MARIA MACHADO MARTINEZ     NaN
# 7     9  2023215111        ANA VANESSA MADRID PEREZ     NaN
# 8    10  2023115002    SERGIO ANDRES MORALES MERCADO    NaN
# 9    11  2023215077  FAIRUZ TATIANA NUNEZ BENAVIDES     NaN
# 10   12  2022115056     KALETH RAFAEL PACHECO GARCIA    NaN
# 11   13  2023115015     VICTOR HUGO PATINO ZAMBRANO     NaN
# 12   14  2020111020        JAIR ALBERTO REYES ELIAS     NaN
# 13   15  2023115041        JUAN JOSE RIVERA MERCHAN     NaN
# 14   16  2023115009   LORENZO RAFAEL ROMERO FONSECA     NaN
# 15   17  2023115010      JUAN GUILLERMO RUIZ GUISAO     NaN
# 16   18  2023215026      JESUS DAVID VARELA MONTERO     NaN
#
#               NombreSinEspacios
# 0   MAICOLGUILLERMOASCANIOSILVA
# 1         LUISMIGUELBECERRADIAZ
# 2        ANDYYULIETHBOLANOSILVA
# 3    DANIELAMARSELABOLANOTORRES
# 4         SAMUELDAVIDGUERRAVEGA
# 5        JORGEANDRESLARAAGUILAR
# 6   NATALIAMARIAMACHADOMARTINEZ
# 7         ANAVANESSAMADRIDPEREZ
# 8    SERGIOANDRESMORALESMERCADO
# 9   FAIRUZTATIANANUNEZBENAVIDES
# 10    KALETHRAFAELPACHECOGARCIA
# 11     VICTORHUGOPATINOZAMBRANO
# 12        JAIRALBERTOREYESELIAS
# 13        JUANJOSERIVERAMERCHAN
# 14   LORENZORAFAELROMEROFONSECA
# 15      JUANGUILLERMORUIZGUISAO
# 16      JESUSDAVIDVARELAMONTERO

# %%
fecha="04-04-2025"
asistencia= pd.read_csv("C:\\Users\\User\\Downloads\\ControlAsistencia\\Viernes\\"+fecha+".csv",sep="\t",encoding="UTF-16")
asistencia['Nombre1']=asistencia['Nombre completo'].str.replace(" ","")
display(asistencia)
# Out:
#                    Nombre completo Acción del usuario  Marca de tiempo  \
# 0             Daniel Gonzalez Polo              Unido              NaN
# 1        JORGE ANDRES LARA AGUILAR              Unido              NaN
# 2        JORGE ANDRES LARA AGUILAR           Abandonó              NaN
# 3      JESUS DAVID  VARELA MONTERO              Unido              NaN
# 4        ANDY YULIETH BOLANO SILVA              Unido              NaN
# 5        ANDY YULIETH BOLANO SILVA           Abandonó              NaN
# 6        ANDY YULIETH BOLANO SILVA              Unido              NaN
# 7        ANDY YULIETH BOLANO SILVA           Abandonó              NaN
# 8        ANDY YULIETH BOLANO SILVA              Unido              NaN
# 9        ANDY YULIETH BOLANO SILVA           Abandonó              NaN
# 10       ANDY YULIETH BOLANO SILVA              Unido              NaN
# 11  FAIRUZ TATIANA NUNEZ BENAVIDES              Unido              NaN
# 12  NATALIA MARIA MACHADO MARTINEZ              Unido              NaN
# 13   SERGIO ANDRES MORALES MERCADO              Unido              NaN
# 14   SERGIO ANDRES MORALES MERCADO           Abandonó              NaN
# 15   SERGIO ANDRES MORALES MERCADO              Unido              NaN
# 16   DANIELA MARSELA BOLANO TORRES              Unido              NaN
# 17        SAMUEL DAVID GUERRA VEGA              Unido              NaN
# 18        SAMUEL DAVID GUERRA VEGA           Abandonó              NaN
# 19        SAMUEL DAVID GUERRA VEGA              Unido              NaN
# 20    KALETH RAFAEL PACHECO GARCIA              Unido              NaN
# 21  MAICOL GUILLERMO ASCANIO SILVA              Unido              NaN
# 22        JAIR ALBERTO REYES ELIAS              Unido              NaN
# 23        JAIR ALBERTO REYES ELIAS           Abandonó              NaN
# 24        JAIR ALBERTO REYES ELIAS              Unido              NaN
# 25   LORENZO RAFAEL ROMERO FONSECA              Unido              NaN
# 26   LORENZO RAFAEL ROMERO FONSECA           Abandonó              NaN
# 27        JUAN JOSE RIVERA MERCHAN              Unido              NaN
# 28        JUAN JOSE RIVERA MERCHAN           Abandonó              NaN
# 29        JUAN JOSE RIVERA MERCHAN              Unido              NaN
# 30        JUAN JOSE RIVERA MERCHAN           Abandonó              NaN
# 31      JUAN GUILLERMO RUIZ GUISAO              Unido              NaN
# 32      JUAN GUILLERMO RUIZ GUISAO           Abandonó              NaN
# 33    VICTOR HUGO  PATINO ZAMBRANO              Unido              NaN
# 34        LUIS MIGUEL BECERRA DIAZ              Unido              NaN
# 35        LUIS MIGUEL BECERRA DIAZ           Abandonó              NaN
# 36        LUIS MIGUEL BECERRA DIAZ              Unido              NaN
# 37        ANA VANESSA MADRID PEREZ              Unido              NaN
# 38        ANA VANESSA MADRID PEREZ           Abandonó              NaN
# 39        ANA VANESSA MADRID PEREZ              Unido              NaN
# 40        ANA VANESSA MADRID PEREZ           Abandonó              NaN
# 41        ANA VANESSA MADRID PEREZ              Unido              NaN
#
#                         Nombre1
# 0            DanielGonzalezPolo
# 1        JORGEANDRESLARAAGUILAR
# 2        JORGEANDRESLARAAGUILAR
# 3       JESUSDAVIDVARELAMONTERO
# 4        ANDYYULIETHBOLANOSILVA
# 5        ANDYYULIETHBOLANOSILVA
# 6        ANDYYULIETHBOLANOSILVA
# 7        ANDYYULIETHBOLANOSILVA
# 8        ANDYYULIETHBOLANOSILVA
# 9        ANDYYULIETHBOLANOSILVA
# 10       ANDYYULIETHBOLANOSILVA
# 11  FAIRUZTATIANANUNEZBENAVIDES
# 12  NATALIAMARIAMACHADOMARTINEZ
# 13   SERGIOANDRESMORALESMERCADO
# 14   SERGIOANDRESMORALESMERCADO
# 15   SERGIOANDRESMORALESMERCADO
# 16   DANIELAMARSELABOLANOTORRES
# 17        SAMUELDAVIDGUERRAVEGA
# 18        SAMUELDAVIDGUERRAVEGA
# 19        SAMUELDAVIDGUERRAVEGA
# 20    KALETHRAFAELPACHECOGARCIA
# 21  MAICOLGUILLERMOASCANIOSILVA
# 22        JAIRALBERTOREYESELIAS
# 23        JAIRALBERTOREYESELIAS
# 24        JAIRALBERTOREYESELIAS
# 25   LORENZORAFAELROMEROFONSECA
# 26   LORENZORAFAELROMEROFONSECA
# 27        JUANJOSERIVERAMERCHAN
# 28        JUANJOSERIVERAMERCHAN
# 29        JUANJOSERIVERAMERCHAN
# 30        JUANJOSERIVERAMERCHAN
# 31      JUANGUILLERMORUIZGUISAO
# 32      JUANGUILLERMORUIZGUISAO
# 33     VICTORHUGOPATINOZAMBRANO
# 34        LUISMIGUELBECERRADIAZ
# 35        LUISMIGUELBECERRADIAZ
# 36        LUISMIGUELBECERRADIAZ
# 37        ANAVANESSAMADRIDPEREZ
# 38        ANAVANESSAMADRIDPEREZ
# 39        ANAVANESSAMADRIDPEREZ
# 40        ANAVANESSAMADRIDPEREZ
# 41        ANAVANESSAMADRIDPEREZ

# %% [markdown]
# ## Control asistencia

# %% [markdown]
# ## Verificar Asistencia

# %%
asistenciaNoRepetida=asistencia["Nombre1"].unique()

asistio = set()
noAsistio=[]
for nses, n in   zip(matriculados["NombreSinEspacios"],matriculados["Nombre"]):    
    if nses in asistenciaNoRepetida:
        asistio.add(n) 
    else:
        noAsistio.append(n)   
    

print("\n Asistió.........\n")
for e in asistio:
    print(e)

print("\n------------No Asisitió-------------- ")
for na in noAsistio:
    print(na)
# Out:
#  Asistió.........
#
# MAICOL GUILLERMO ASCANIO SILVA
# JORGE ANDRES LARA AGUILAR
#  SERGIO ANDRES MORALES MERCADO
# FAIRUZ TATIANA NUNEZ BENAVIDES
# ANDY YULIETH BOLANO  SILVA
# NATALIA MARIA MACHADO MARTINEZ
#  KALETH RAFAEL PACHECO GARCIA
# DANIELA MARSELA BOLANO TORRES
# JUAN GUILLERMO RUIZ GUISAO
# ANA VANESSA MADRID PEREZ
# VICTOR HUGO PATINO ZAMBRANO
# JUAN JOSE RIVERA MERCHAN
# JESUS DAVID VARELA MONTERO
# LORENZO RAFAEL ROMERO FONSECA
# SAMUEL DAVID GUERRA VEGA
# LUIS MIGUEL BECERRA DIAZ
# JAIR ALBERTO REYES ELIAS
#
# ------------No Asisitió--------------

# %% [markdown]
# ## Genera Archivo de Inasistencia

# %%
dfInasistencia = pd.DataFrame(noAsistio, columns=['Nombre Estudiante'])
dfInasistencia["Fecha"]=fecha

Inasistencia= pd.read_excel("C:\\Users\\User\\Downloads\\ControlAsistencia\\Viernes\\InasistenciaViernes.xlsx") 
frames = [Inasistencia,dfInasistencia]
result = pd.concat(frames)
result.to_excel("C:\\Users\\User\\Downloads\\ControlAsistencia\\Viernes\\InasistenciaViernes.xlsx",index=False)
print(result)
# Out:
#                 Nombre Estudiante       Fecha
# 0       JAIR ALBERTO REYES ELIAS   07-02-2025
# 1       JUAN JOSE RIVERA MERCHAN   28-02-2025
# 2   SERGIO ANDRES MORALES MERCADO  21-03-2025
