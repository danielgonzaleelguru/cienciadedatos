# %% [markdown]
# # Manejo de Archivos en formato Excel y CSV.

# %%
import pandas as pd
import numpy as np

# %%
Path ="datosDepartamentos.csv"
df = pd.read_csv(Path)
display(df)
# Out:
#       CodDepart  Código Municipio  Código Centro Poblado Nombre Departamento  \
# 0             5              5001                5001000           ANTIOQUIA
# 1             5              5001                5001001           ANTIOQUIA
# 2             5              5001                5001004           ANTIOQUIA
# 3             5              5001                5001009           ANTIOQUIA
# 4             5              5001                5001010           ANTIOQUIA
# ...         ...               ...                    ...                 ...
# 8160         99             99773               99773028             VICHADA
# 8161         99             99773               99773029             VICHADA
# 8162         99             99773               99773030             VICHADA
# 8163         99             99773               99773031             VICHADA
# 8164         99             99773               99773032             VICHADA
#
# ...

# %%
copyDf = df[df['CodDepart']==5]
display(copyDf)
# Out:
#      CodDepart  Código Municipio  Código Centro Poblado Nombre Departamento  \
# 0            5              5001                5001000           ANTIOQUIA
# 1            5              5001                5001001           ANTIOQUIA
# 2            5              5001                5001004           ANTIOQUIA
# 3            5              5001                5001009           ANTIOQUIA
# 4            5              5001                5001010           ANTIOQUIA
# ..         ...               ...                    ...                 ...
# 754          5              5895                5895004           ANTIOQUIA
# 755          5              5895                5895008           ANTIOQUIA
# 756          5              5895                5895009           ANTIOQUIA
# 757          5              5895                5895010           ANTIOQUIA
# 758          5              5895                5895011           ANTIOQUIA
#
# ...

# %%
conteos = copyDf.groupby(['TipoPoblado'])['TipoPoblado'].count()
display(conteos)
# Out:
# TipoPoblado
# CABECERA MUNICIPAL    125
# CENTRO POBLADO        634
# Name: TipoPoblado, dtype: int64

# %%
vector =df[["CodDepart"]].to_numpy()
np.max(vector)
# Out:
# np.int64(99)
