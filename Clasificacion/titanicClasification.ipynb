# %% [markdown]
# ## Titanic Survived

# %%
import pandas as pd 

data = pd.read_csv("E:\\Weka\\data\\train.csv")
display(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(data.isnull().sum().sum()) ## total misising values .
print(data.isnull().sum()) ## total misising values.
# Out:
# 866
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(data.iloc[0])
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data["Cabin"].fillna(data['Cabin'].mode()[0])
display(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["Age"].fillna(data['Age'].mean())
display(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
feature_cols=['PassengerId','Pclass','Age','SibSp','Parch','Fare',]
X= data[feature_cols]
display(X)
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0              1       3  22.0      1      0   7.2500
# 1              2       1  38.0      1      0  71.2833
# 2              3       3  26.0      0      0   7.9250
# 3              4       1  35.0      1      0  53.1000
# 4              5       3  35.0      0      0   8.0500
# ..           ...     ...   ...    ...    ...      ...
# 886          887       2  27.0      0      0  13.0000
# 887          888       1  19.0      0      0  30.0000
# 888          889       3   NaN      1      2  23.4500
# 889          890       1  26.0      0      0  30.0000
# 890          891       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
Y=data.Survived
display(Y)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
Xtrain, X_test,Y_train, Y_test  = train_test_split(X,Y,test_size=0.80,random_state=100,shuffle=True)

# %%
print(Xtrain.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (178, 6)
# (713, 6)
# (178,)
# (713,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

model = DecisionTreeClassifier()
clf = model.fit(Xtrain,Y_train)
y_pred = model.predict(X_test)

print("Accuracy:",metrics.accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.635343618513324

# %%
from sklearn import tree
tree.plot_tree(clf)
# Out:
# [Text(0.565625, 0.9705882352941176, 'x[5] <= 77.623\ngini = 0.457\nsamples = 178\nvalue = [115.0, 63.0]'),
#  Text(0.30625, 0.9117647058823529, 'x[5] <= 7.91\ngini = 0.431\nsamples = 162\nvalue = [111.0, 51.0]'),
#  Text(0.43593750000000003, 0.9411764705882353, 'True  '),
#  Text(0.125, 0.8529411764705882, 'x[2] <= 23.5\ngini = 0.268\nsamples = 44\nvalue = [37, 7]'),
#  Text(0.05, 0.7941176470588235, 'x[0] <= 137.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.025, 0.7352941176470589, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.075, 0.7352941176470589, 'x[0] <= 203.0\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.05, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1, 0.6764705882352942, 'x[2] <= 22.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.075, 0.6176470588235294, 'x[0] <= 267.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.05, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
from sklearn.tree import export_text
r = export_text(clf, feature_names=feature_cols)
print(r)
# Out:
# |--- Fare <= 77.62
# |   |--- Fare <= 7.91
# |   |   |--- Age <= 23.50
# |   |   |   |--- PassengerId <= 137.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- PassengerId >  137.00
# |   |   |   |   |--- PassengerId <= 203.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- PassengerId >  203.00
# |   |   |   |   |   |--- Age <= 22.50
# |   |   |   |   |   |   |--- PassengerId <= 267.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PassengerId >  267.00
# |   |   |   |   |   |   |   |--- Fare <= 7.76
# |   |   |   |   |   |   |   |   |--- Age <= 21.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Age >  21.00
# |   |   |   |   |   |   |   |   |   |--- PassengerId <= 384.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PassengerId >  384.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Fare >  7.76
# ...
