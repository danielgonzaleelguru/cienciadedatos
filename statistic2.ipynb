# %%
import matplotlib.pyplot as plot
import numpy as np
import scipy.stats as stats

# %%
data = np.arange(0,10,0.1)
data2 =np.random.randn(500)
c=np.cos(data)
s = np.sin(data)

plot.plot(data2,'.')

# %%
plot.hist(data2)
# Out:
# (array([ 13.,  15.,  47.,  71.,  91., 120.,  75.,  40.,  19.,   9.]),
#  array([-2.68801379, -2.14904303, -1.61007226, -1.0711015 , -0.53213074,
#          0.00684002,  0.54581078,  1.08478154,  1.6237523 ,  2.16272306,
#          2.70169383]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
df =pd.DataFrame({'Time':data,'x':c, 'y':c})
print(df)
# Out:
#     Time         x         y
# 0    0.0  1.000000  1.000000
# 1    0.1  0.995004  0.995004
# 2    0.2  0.980067  0.980067
# 3    0.3  0.955336  0.955336
# 4    0.4  0.921061  0.921061
# ..   ...       ...       ...
# 95   9.5 -0.997172 -0.997172
# 96   9.6 -0.984688 -0.984688
# 97   9.7 -0.962365 -0.962365
# 98   9.8 -0.930426 -0.930426
# 99   9.9 -0.889191 -0.889191
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Comparativa de histograma y la  curva de densdad kernel

# %%
import seaborn as sns
x = [-2.1, -1.3, -0.4, 1.9, 5.1, 6.2]

sns.kdeplot(x)
plot.hist(x)
# Out:
# (array([2., 0., 1., 0., 1., 0., 0., 0., 1., 1.]),
#  array([-2.1 , -1.27, -0.44,  0.39,  1.22,  2.05,  2.88,  3.71,  4.54,
#          5.37,  6.2 ]),
#  <BarContainer object of 10 artists>)

# %%
plot.plot(stats.cumfreq(x,50)[0])
