# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
workbook="data.xlsx"
df=pd.read_excel(workbook)

newDatos= df[(df['Duracion']>5) & (df['Duracion']<6)]
display(newDatos)
print(newDatos.info())
# Out:
#                      Fecha  Valor  Duracion  Intensidad  \
# 14879  2017-05-06 06:00:00   0.04       5.5    1.263636
# 14880  2017-05-06 06:10:00   0.08       5.5    1.263636
# 14881  2017-05-06 06:20:00   0.02       5.5    1.263636
# 14882  2017-05-06 06:30:00   0.18       5.5    1.263636
# 14883  2017-05-06 06:40:00   0.20       5.5    1.263636
# ...                    ...    ...       ...         ...
# 70355  2020-09-08 04:40:00   0.20       5.5    3.036364
# 70356  2020-09-08 04:50:00   0.20       5.5    3.036364
# 70357  2020-09-08 05:00:00   0.10       5.5    3.036364
# 70358  2020-09-08 05:10:00   0.10       5.5    3.036364
# 70359  2020-09-08 05:20:00   0.20       5.5    3.036364
#
#        Intesidad maxima en 10 minutos  Intensidad maxima por evento
# 14879                            0.28                           2.2
# 14880                            0.56                           2.2
# 14881                            0.80                           2.2
# ...

# %%
newDatos['Fecha2'] = None
newDatos['Hora'] = None
newDatos['HoraCompleta']=None
display(newDatos)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24268\2084002165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDatos['Fecha2'] = None
# C:\Users\User\AppData\Local\Temp\ipykernel_24268\2084002165.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDatos['Hora'] = None
# C:\Users\User\AppData\Local\Temp\ipykernel_24268\2084002165.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
def getDateColumn(x):
    return x.split(" ")[0]

def getTimeColumn(x):
    return x.split(" ")[1].split(":")[0]

def convertHourToMin(x):

# %%
newDatos['Fecha2']=newDatos['Fecha'].apply(getDateColumn)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24268\214841996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDatos['Fecha2']=newDatos['Fecha'].apply(getDateColumn)

# %%
newDatos['Hora']=newDatos['Fecha'].apply(getTimeColumn)
display(newDatos)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24268\1837475228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDatos['Hora']=newDatos['Fecha'].apply(getTimeColumn)
#                      Fecha  Valor  Duracion  Intensidad  \
# 14879  2017-05-06 06:00:00   0.04       5.5    1.263636
# 14880  2017-05-06 06:10:00   0.08       5.5    1.263636
# 14881  2017-05-06 06:20:00   0.02       5.5    1.263636
# 14882  2017-05-06 06:30:00   0.18       5.5    1.263636
# 14883  2017-05-06 06:40:00   0.20       5.5    1.263636
# ...                    ...    ...       ...         ...
# 70355  2020-09-08 04:40:00   0.20       5.5    3.036364
# 70356  2020-09-08 04:50:00   0.20       5.5    3.036364
# ...

# %%
newDatos.groupby('Fecha2')
display(newDatos)
# Out:
#                      Fecha  Valor  Duracion  Intensidad  \
# 14879  2017-05-06 06:00:00   0.04       5.5    1.263636
# 14880  2017-05-06 06:10:00   0.08       5.5    1.263636
# 14881  2017-05-06 06:20:00   0.02       5.5    1.263636
# 14882  2017-05-06 06:30:00   0.18       5.5    1.263636
# 14883  2017-05-06 06:40:00   0.20       5.5    1.263636
# ...                    ...    ...       ...         ...
# 70355  2020-09-08 04:40:00   0.20       5.5    3.036364
# 70356  2020-09-08 04:50:00   0.20       5.5    3.036364
# 70357  2020-09-08 05:00:00   0.10       5.5    3.036364
# 70358  2020-09-08 05:10:00   0.10       5.5    3.036364
# 70359  2020-09-08 05:20:00   0.20       5.5    3.036364
#
#        Intesidad maxima en 10 minutos  Intensidad maxima por evento  \
# 14879                            0.28                           2.2
# 14880                            0.56                           2.2
# 14881                            0.80                           2.2
# ...

# %%
df3=newDatos.groupby(['Fecha2','Hora'])['Valor'].sum()
display(df3)
# Out:
# Fecha2      Hora
# 2017-05-06  06      0.66
#             07      1.86
#             08      0.89
#             09      1.09
#             10      1.93
#             11      0.52
# 2020-09-08  00      1.30
#             01      4.90
#             02      2.40
#             03      5.70
#             04      2.00
#             05      0.40
# Name: Valor, dtype: float64

# %%
ax = df3.plot(kind='line', title='Serie Temporal de Precipitación', figsize=(10, 6))
ax.set_ylabel("Valores acumulados de Precipitación")
ax.set_xlabel("Hora del Día")
ax.grid(True)
ax.set_yscale('log')
ax.legend(loc="upper left")

# %% [markdown]
# ## Interpolación

# %%
import numpy as np
import matplotlib.pyplot as plt

# arrays with random data points
x = np.array([1, 2,3,4,5,6])
y = np.array([0.52,0.66,0.88,1.09,1.86,1.93]) 


# generate evenly spaced values between the minimum and maximum x values
x_interp = np.linspace(x.min(), x.max(), 100)

# interp() to interpolate y values
y_interp = np.interp(x_interp, x, y)

# plot the original data points and the interpolated values
plt.plot(x, y, 'bo')
plt.plot(x_interp, y_interp, 'r-')

plt.show()
